# %%
#We will continue from the previous dataset

import pandas as pd

realEstTrans = pd.read_csv('../input/Sacramentorealestatetransactions.csv')
realEstTrans.head(50)
# Out:
#                              street     ...       longitude
# 0                      3526 HIGH ST     ...     -121.434879
# 1                       51 OMAHA CT     ...     -121.431028
# 2                    2796 BRANCH ST     ...     -121.443839
# 3                  2805 JANETTE WAY     ...     -121.439146
# 4                   6001 MCMAHON DR     ...     -121.435768
# 5                5828 PEPPERMILL CT     ...     -121.327813
# 6               6048 OGDEN NASH WAY     ...     -121.351705
# 7                     2561 19TH AVE     ...     -121.481367
# 8   11150 TRINITY RIVER DR Unit 114     ...     -121.270555
# 9                      7325 10TH ST     ...     -121.442979
# 10                 645 MORRISON AVE     ...     -121.451520
# 11                    4085 FAWN CIR     ...     -121.458918
# 12                  2930 LA ROSA RD     ...     -121.435833
# 13                    2113 KIRK WAY     ...     -121.492603
# 14              4533 LOCH HAVEN WAY     ...     -121.359340
# 15                   7340 HAMDEN PL     ...     -121.351278
# 16                      6715 6TH ST     ...     -121.452239
# 17          6236 LONGFORD DR Unit 1     ...     -121.314089
# 18                  250 PERALTA AVE     ...     -121.469095
# 19                  113 LEEWILL AVE     ...     -121.463220
# 20               6118 STONEHAND AVE     ...     -121.320707
# 21                4882 BANDALIN WAY     ...     -121.444071
# 22                  7511 OAKVALE CT     ...     -121.382210
# 23                     9 PASTURE CT     ...     -121.488097
# 24               3729 BAINBRIDGE DR     ...     -121.376220
# 25               3828 BLACKFOOT WAY     ...     -121.373770
# 26                  4108 NORTON WAY     ...     -121.478315
# 27                 1469 JANRICK AVE     ...     -121.501711
# 28                    9861 CULP WAY     ...     -121.327948
# 29            7825 CREEK VALLEY CIR     ...     -121.404199
# 30     5201 LAGUNA OAKS DR Unit 140     ...     -121.444489
# 31                   6768 MEDORA DR     ...     -121.371920
# 32                 3100 EXPLORER DR     ...     -121.332644
# 33                7944 DOMINION WAY     ...     -121.411227
# 34     5201 LAGUNA OAKS DR Unit 162     ...     -121.444489
# 35             3920 SHINING STAR DR     ...     -121.462459
# 36                  5031 CORVAIR ST     ...     -121.375469
# 37                   7661 NIXOS WAY     ...     -121.463317
# 38                  7044 CARTHY WAY     ...     -121.420925
# 39                 2442 LARKSPUR LN     ...     -121.403736
# 40     4800 WESTLAKE PKWY Unit 2109     ...     -121.542345
# 41                    2178 63RD AVE     ...     -121.489660
# 42                     8718 ELK WAY     ...     -121.379653
# 43               5708 RIDGEPOINT DR     ...     -121.331555
# 44                    7315 KOALA CT     ...     -121.371414
# 45                     2622 ERIN DR     ...     -121.488694
# 46                8421 SUNBLAZE WAY     ...     -121.432538
# 47                   7420 ALIX PKWY     ...     -121.452811
# 48                  3820 NATOMA WAY     ...     -121.422159
# 49               4431 GREEN TREE DR     ...     -121.454469
#
# [50 rows x 12 columns]

# %%
#Let's try to do some filtering
#Let's say you want to get all the data where the 'street' has the word 'WAY'in it

realEstTrans.loc[realEstTrans['street'].str.contains('WAY')]
#Now will say all the results will have streets that contains the word 'WAY'
#realEstTrans.loc[~realEstTrans['street'].str.contains('WAY')]
#The above line with the character '~' is similar to a NOT operator. Try it out
# Out:
#                     street             city     ...       latitude   longitude
# 3         2805 JANETTE WAY       SACRAMENTO     ...      38.616835 -121.439146
# 6      6048 OGDEN NASH WAY       SACRAMENTO     ...      38.681659 -121.351705
# 13           2113 KIRK WAY       SACRAMENTO     ...      38.482215 -121.492603
# 14     4533 LOCH HAVEN WAY       SACRAMENTO     ...      38.672914 -121.359340
# 21       4882 BANDALIN WAY       SACRAMENTO     ...      38.468173 -121.444071
# 25      3828 BLACKFOOT WAY         ANTELOPE     ...      38.709740 -121.373770
# 26         4108 NORTON WAY       SACRAMENTO     ...      38.537526 -121.478315
# 28           9861 CULP WAY       SACRAMENTO     ...      38.558423 -121.327948
# 33       7944 DOMINION WAY          ELVERTA     ...      38.713182 -121.411227
# 37          7661 NIXOS WAY       SACRAMENTO     ...      38.479553 -121.463317
# 38         7044 CARTHY WAY       SACRAMENTO     ...      38.498570 -121.420925
# 42            8718 ELK WAY        ELK GROVE     ...      38.416530 -121.379653
# 46       8421 SUNBLAZE WAY       SACRAMENTO     ...      38.450543 -121.432538
# 48         3820 NATOMA WAY       SACRAMENTO     ...      38.636748 -121.422159
# 51       8299 HALBRITE WAY       SACRAMENTO     ...      38.473814 -121.400000
# 53      8156 STEINBECK WAY       SACRAMENTO     ...      38.474853 -121.406326
# 56         4520 BOMARK WAY       SACRAMENTO     ...      38.665724 -121.358576
# 60      4844 CLYDEBANK WAY         ANTELOPE     ...      38.714609 -121.347887
# 61        306 CAMELLIA WAY             GALT     ...      38.260443 -121.297864
# 64    8317 SUNNY CREEK WAY       SACRAMENTO     ...      38.459041 -121.424644
# 66          7005 TIANT WAY        ELK GROVE     ...      38.422811 -121.423285
# 67          7895 CABER WAY         ANTELOPE     ...      38.711279 -121.393449
# 69   6930 HAMPTON COVE WAY       SACRAMENTO     ...      38.440040 -121.421012
# 70     8708 MESA BROOK WAY        ELK GROVE     ...      38.440760 -121.385792
# 75   8345 STAR THISTLE WAY       SACRAMENTO     ...      38.454349 -121.439239
# 76         9080 FRESCA WAY        ELK GROVE     ...      38.427818 -121.424026
# 78       8373 BLACKMAN WAY        ELK GROVE     ...      38.435436 -121.394536
# 85     4243 MIDDLEBURY WAY           MATHER     ...      38.547991 -121.280483
# 90        6913 RICHEVE WAY       SACRAMENTO     ...      38.502519 -121.420769
# 91          8636 TEGEA WAY        ELK GROVE     ...      38.443832 -121.382087
# ..                     ...              ...     ...            ...         ...
# 900       2636 TRONERO WAY   RANCHO CORDOVA     ...      38.593049 -121.303040
# 902        3604 KODIAK WAY         ANTELOPE     ...      38.706175 -121.379776
# 903       2149 COTTAGE WAY       SACRAMENTO     ...      38.603593 -121.417011
# 910      8636 LONGSPUR WAY         ANTELOPE     ...      38.725873 -121.358560
# 911    1941 EXPEDITION WAY       SACRAMENTO     ...      38.473775 -121.493777
# 913       6513 HOLIDAY WAY  NORTH HIGHLANDS     ...      38.685361 -121.376938
# 914     8321 MISTLETOE WAY   CITRUS HEIGHTS     ...      38.717738 -121.308322
# 915   5920 VALLEY GLEN WAY       SACRAMENTO     ...      38.462821 -121.433135
# 916  2601 SAN FERNANDO WAY       SACRAMENTO     ...      38.556178 -121.476256
# 920     1001 RIO NORTE WAY       SACRAMENTO     ...      38.634292 -121.485106
# 935     1080 RIO NORTE WAY       SACRAMENTO     ...      38.634335 -121.486098
# 936      5501 VALLETTA WAY       SACRAMENTO     ...      38.530144 -121.437490
# 941       1973 DANVERS WAY       SACRAMENTO     ...      38.477568 -121.492574
# 943       7409 VOYAGER WAY   CITRUS HEIGHTS     ...      38.700717 -121.313300
# 945  5509 LAGUNA CREST WAY        ELK GROVE     ...      38.424420 -121.440357
# 946    8424 MERRY HILL WAY        ELK GROVE     ...      38.452075 -121.366461
# 952      3230 SMATHERS WAY       CARMICHAEL     ...      38.623372 -121.347665
# 953  5209 LAGUNA CREST WAY        ELK GROVE     ...      38.424421 -121.443915
# 955        2100 BEATTY WAY        ROSEVILLE     ...      38.737882 -121.308142
# 956    6920 GILLINGHAM WAY  NORTH HIGHLANDS     ...      38.694279 -121.373395
# 959    8428 MISTY PASS WAY         ANTELOPE     ...      38.722959 -121.347115
# 960      7958 ROSEVIEW WAY       SACRAMENTO     ...      38.467836 -121.410366
# 962    7809 VALLECITOS WAY       SACRAMENTO     ...      38.508217 -121.411207
# 967        5429 HESPER WAY       CARMICHAEL     ...      38.665104 -121.315901
# 970          3557 SODA WAY       SACRAMENTO     ...      38.631026 -121.501879
# 972      7381 WASHBURN WAY  NORTH HIGHLANDS     ...      38.703550 -121.375103
# 979       1909 YARNELL WAY        ELK GROVE     ...      38.417382 -121.484325
# 981        6932 RUSKUT WAY       SACRAMENTO     ...      38.499893 -121.458890
# 982      7933 DAFFODIL WAY   CITRUS HEIGHTS     ...      38.708824 -121.256803
# 983       8304 RED FOX WAY        ELK GROVE     ...      38.417000 -121.397424
#
# [306 rows x 12 columns]

# %%
#Lets's go a step further
#We can also use regex for more complex operations
#Say we need to know the rows where 'street' has either the words 'ST' or 'AVE'
import re
realEstTrans.loc[realEstTrans['street'].str.contains('st|ave', flags=re.I, regex=True)]

#Here we initialy import the regex library, then we use it in our method
#As you can see i have typed in lower case 'st|ave' even though the data is in UPPER
#But this can be a issue if the data set is very big where we do not know if there were
#any lower case characters. So we use the flags=re.I where we basically say to ignore the case
# Out:
#                            street     ...       longitude
# 0                    3526 HIGH ST     ...     -121.434879
# 2                  2796 BRANCH ST     ...     -121.443839
# 7                   2561 19TH AVE     ...     -121.481367
# 9                    7325 10TH ST     ...     -121.442979
# 10               645 MORRISON AVE     ...     -121.451520
# 14            4533 LOCH HAVEN WAY     ...     -121.359340
# 16                    6715 6TH ST     ...     -121.452239
# 18                250 PERALTA AVE     ...     -121.469095
# 19                113 LEEWILL AVE     ...     -121.463220
# 20             6118 STONEHAND AVE     ...     -121.320707
# 23                   9 PASTURE CT     ...     -121.488097
# 27               1469 JANRICK AVE     ...     -121.501711
# 35           3920 SHINING STAR DR     ...     -121.462459
# 36                5031 CORVAIR ST     ...     -121.375469
# 40   4800 WESTLAKE PKWY Unit 2109     ...     -121.542345
# 41                  2178 63RD AVE     ...     -121.489660
# 50                   9417 SARA ST     ...     -121.370527
# 53             8156 STEINBECK WAY     ...     -121.406326
# 58              5332 SANDSTONE ST     ...     -121.313945
# 62               9021 MADISON AVE     ...     -121.217511
# 63                     404 6TH ST     ...     -121.302493
# 75          8345 STAR THISTLE WAY     ...     -121.439239
# 88          7713 HARVEST WOODS DR     ...     -121.412911
# 89               2866 KARITSA AVE     ...     -121.525970
# 92             5448 MAIDSTONE WAY     ...     -121.293288
# 99                   4900 71ST ST     ...     -121.421089
# 105                  6850 21ST ST     ...     -121.490795
# 112               1838 CASTRO WAY     ...     -121.490787
# 114               7731 MASTERS ST     ...     -121.410873
# 119         9570 HARVEST ROSE WAY     ...     -121.340352
# ..                            ...     ...             ...
# 872                701 JESSIE AVE     ...     -121.449562
# 876               4113 DAYSTAR CT     ...     -121.458606
# 879            3935 LIMESTONE WAY     ...     -121.463157
# 882                 4225 46TH AVE     ...     -121.457676
# 883                 1434 BELL AVE     ...     -121.432914
# 885                  7629 BETH ST     ...     -121.487869
# 888        3035 ESTEPA DR Unit 5C     ...     -120.996713
# 892               1691 NOGALES ST     ...     -121.427775
# 893                  3118 42ND ST     ...     -121.457745
# 894                 7517 50TH AVE     ...     -121.416267
# 896                 7928 36TH AVE     ...     -121.411383
# 898                  7043 9TH AVE     ...     -121.444133
# 905                612 STONE BLVD     ...     -121.535579
# 906                 4180 12TH AVE     ...     -121.458129
# 907          8025 ARROYO VISTA DR     ...     -121.419029
# 914            8321 MISTLETOE WAY     ...     -121.308322
# 917                501 POPLAR AVE     ...     -121.534609
# 921                      604 P ST     ...     -121.305398
# 924             7740 DIXIE LOU ST     ...     -121.477039
# 925                  7342 DAVE ST     ...     -121.401643
# 942          8001 ARROYO VISTA DR     ...     -121.419843
# 945         5509 LAGUNA CREST WAY     ...     -121.440357
# 947         1525 PENNSYLVANIA AVE     ...     -121.527539
# 951                  2221 2ND AVE     ...     -121.485331
# 953         5209 LAGUNA CREST WAY     ...     -121.443915
# 954                416 LEITCH AVE     ...     -121.456669
# 959           8428 MISTY PASS WAY     ...     -121.347115
# 973          2181 WINTERHAVEN CIR     ...     -120.995739
# 974              7540 HICKORY AVE     ...     -121.235221
# 984           3882 YELLOWSTONE LN     ...     -121.075915
#
# [253 rows x 12 columns]

# %%
#Let's say you want to find all the records where the 'street' number begins from a 4
realEstTrans.loc[realEstTrans['street'].str.contains('^4[0-9]*', flags=re.I, regex=True)]

#Here we use the basic rules of regex as in python. Play around to know more
# Out:
#                            street     ...       longitude
# 11                  4085 FAWN CIR     ...     -121.458918
# 14            4533 LOCH HAVEN WAY     ...     -121.359340
# 21              4882 BANDALIN WAY     ...     -121.444071
# 26                4108 NORTON WAY     ...     -121.478315
# 40   4800 WESTLAKE PKWY Unit 2109     ...     -121.542345
# 49             4431 GREEN TREE DR     ...     -121.454469
# 56                4520 BOMARK WAY     ...     -121.358576
# 60             4844 CLYDEBANK WAY     ...     -121.347887
# 63                     404 6TH ST     ...     -121.302493
# 85            4243 MIDDLEBURY WAY     ...     -121.280483
# 87                4804 NORIKER DR     ...     -121.448424
# 94                   4010 ALEX LN     ...     -121.312963
# 95               4901 MILLNER WAY     ...     -121.447349
# 96           4818 BRITTNEY LEE CT     ...     -121.342180
# 99                   4900 71ST ST     ...     -121.421089
# 101       4236 NATOMAS CENTRAL DR     ...     -121.544023
# 115             4925 PERCHERON DR     ...     -121.447649
# 117               4727 SAVOIE WAY     ...     -121.549521
# 120                4359 CREGAN CT     ...     -121.224922
# 124               4620 WELERA WAY     ...     -121.450148
# 131           4143 SEA MEADOW WAY     ...     -121.457519
# 146           4186 TULIP PARK WAY     ...     -121.235260
# 155               4070 REDONDO DR     ...     -121.064830
# 156               4004 CRESTA WAY     ...     -121.370626
# 164               483 ARCADE BLVD     ...     -121.454884
# 177               4803 MCCLOUD DR     ...     -121.352817
# 196              4207 PAINTER WAY     ...     -121.367497
# 200            4660 CEDARWOOD WAY     ...     -121.449316
# 205           4524 LOCH HAVEN WAY     ...     -121.359645
# 207                 4631 11TH AVE     ...     -121.452132
# ..                            ...     ...             ...
# 635                4288 DYMIC WAY     ...     -121.441139
# 637                   4904 J PKWY     ...     -121.442950
# 641             4055 DEERBROOK DR     ...     -121.459589
# 644                 4909 RUGER CT     ...     -121.349234
# 651             4517 OLYMPIAD WAY     ...     -121.359154
# 658          4008 GREY LIVERY WAY     ...     -121.370862
# 662             4480 VALLEY HI DR     ...     -121.450955
# 680               435 EXCHANGE ST     ...     -121.455236
# 683            4854 TANGERINE AVE     ...     -121.446326
# 685            4290 BLACKFORD WAY     ...     -121.454162
# 729               4085 COUNTRY DR     ...     -121.369509
# 736                 4240 WINJE DR     ...     -121.359559
# 769              4636 TEAL BAY CT     ...     -121.354753
# 793                  4204 LUSK DR     ...     -121.368424
# 799                448 ELMWOOD CT     ...     -121.304439
# 810               4821 HUTSON WAY     ...     -121.448159
# 811                 4509 WINJE DR     ...     -121.359357
# 816             4165 BRISBANE CIR     ...     -121.073413
# 832                4748 SALEM WAY     ...     -121.353376
# 844          4320 FOUR SEASONS RD     ...     -120.693641
# 850         4841 VILLAGE GREEN DR     ...     -121.056735
# 857              4620 BROMWICH CT     ...     -121.220232
# 859             4478 GREENBRAE RD     ...     -121.222801
# 876               4113 DAYSTAR CT     ...     -121.458606
# 882                 4225 46TH AVE     ...     -121.457676
# 895              4071 EVALITA WAY     ...     -121.458861
# 906                 4180 12TH AVE     ...     -121.458129
# 912            4351 TURNBRIDGE DR     ...     -121.456027
# 954                416 LEITCH AVE     ...     -121.456669
# 969                 4900 ELUDE CT     ...     -121.350519
#
# [108 rows x 12 columns]

# %%
#Let's do some changes to the data
#Suppose we need to replace the 'type' Residential to Normal, we do the following
realEstTrans.loc[realEstTrans['type'] == 'Residential', 'type'] = 'Normal'
realEstTrans.head(10)
#There you go !! We can see 'Residential has been replaced with the word 'Normal'
# Out:
#                             street     ...       longitude
# 0                     3526 HIGH ST     ...     -121.434879
# 1                      51 OMAHA CT     ...     -121.431028
# 2                   2796 BRANCH ST     ...     -121.443839
# 3                 2805 JANETTE WAY     ...     -121.439146
# 4                  6001 MCMAHON DR     ...     -121.435768
# 5               5828 PEPPERMILL CT     ...     -121.327813
# 6              6048 OGDEN NASH WAY     ...     -121.351705
# 7                    2561 19TH AVE     ...     -121.481367
# 8  11150 TRINITY RIVER DR Unit 114     ...     -121.270555
# 9                     7325 10TH ST     ...     -121.442979
#
# [10 rows x 12 columns]

# %%
#We can also do changes to other columns based on conditions of another column
#Let's say you want to change the 'type' to 'Luxury' if the price greater than 90000

realEstTrans.loc[realEstTrans['price'] > 90000, 'type'] = 'Luxury'
realEstTrans.head(10)

#So now you will see the type of house that has a price greater than 90K has been changed as 'Luxury'
#We also can have multiple condition as well as multiple parameters. Do some self exploration on that.
# Out:
#                             street     ...       longitude
# 0                     3526 HIGH ST     ...     -121.434879
# 1                      51 OMAHA CT     ...     -121.431028
# 2                   2796 BRANCH ST     ...     -121.443839
# 3                 2805 JANETTE WAY     ...     -121.439146
# 4                  6001 MCMAHON DR     ...     -121.435768
# 5               5828 PEPPERMILL CT     ...     -121.327813
# 6              6048 OGDEN NASH WAY     ...     -121.351705
# 7                    2561 19TH AVE     ...     -121.481367
# 8  11150 TRINITY RIVER DR Unit 114     ...     -121.270555
# 9                     7325 10TH ST     ...     -121.442979
#
# [10 rows x 12 columns]

# %%
#Let's try to do some aggregate functions
#We can find the average price of different types of residences by using the .mean() method
realEstTrans.groupby(['type']).mean()
# Out:
#                  zip      beds     ...       latitude   longitude
# type                               ...
# Condo   95795.727273  1.909091     ...      38.596735 -121.361818
# Luxury  95753.402715  3.097285     ...      38.593768 -121.356167
# Normal  95718.622222  1.211111     ...      38.746238 -121.353457
#
# [3 rows x 7 columns]

# %%
#We need only price but here you see, we get all the columns additional columns. 
#To solve that problem, we do the following

realEstTrans.groupby(['type']).mean()['price']
#We also can play with various way in this. Please refer the documentation to find out how !!
# Out:
# type
# Condo      69695.727273
# Luxury    256643.505656
# Normal     33250.977778
# Name: price, dtype: float64

# %%
#That's it for this beginners series on the basics of Python Pandas. 
#I hope you would have got a clear idea on how the basics work.
#Leave an upvote if you liked this notenbook
