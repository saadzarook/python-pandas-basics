# %% [markdown]
# Here we will take a look at the **basics of Python Pandas** including some useful functions to actually start your exploration in data science.
# First things first, we need to import the pandas library to our workspace

# %%
import pandas as pd

#Now this is the default way on how we import libararies in python. 
#You may choose any meaningful name in place of 'pd'

# %% [markdown]
# Next we will use make use of the Pandas library
# Initially we need to import our dataset
# I have already attached a sample CSV file which i grabbed from https://support.spatialkey.com/spatialkey-sample-csv-data/
# There is plenty of puclic data sets in Kaggle as well as in other websites for you to play with

# %%
#Now let's bring in our dataset

realEstTrans = pd.read_csv('../input/Sacramentorealestatetransactions.csv')

# %% [markdown]
# If your dataset is in excel format or .xlsx, then we can use the below method
#
# > realEstTrans_xlsx = pd.read_excel('../input/Sacramentorealestatetransactions.xlsx')
#
# If your dataset in tab seperated, space seperated file or .txt, then we use the read.csv method by including a delimiter
# > realEstTrans_txt = pd.read_csv('../input/Sacramentorealestatetransactions.csv', delimiter= '\t')
#
# Try playing around with the methods and GET ERRORS !!! It's where you will learn.

# %%
#To view the dataset in your workspace, we can simple call the name of the variable or use the print function

realEstTrans
# Out:
#                   street             city    zip state  beds  baths  sq__ft  \
# 0           3526 HIGH ST       SACRAMENTO  95838    CA     2      1     836
# 1            51 OMAHA CT       SACRAMENTO  95823    CA     3      1    1167
# 2         2796 BRANCH ST       SACRAMENTO  95815    CA     2      1     796
# 3       2805 JANETTE WAY       SACRAMENTO  95815    CA     2      1     852
# 4        6001 MCMAHON DR       SACRAMENTO  95824    CA     2      1     797
# ..                   ...              ...    ...   ...   ...    ...     ...
# 980   9169 GARLINGTON CT       SACRAMENTO  95829    CA     4      3    2280
# 981      6932 RUSKUT WAY       SACRAMENTO  95823    CA     3      2    1477
# 982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610    CA     3      2    1216
# 983     8304 RED FOX WAY        ELK GROVE  95758    CA     4      2    1685
# 984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762    CA     3      2    1362
#
#             type                     sale_date   price   latitude   longitude
# 0    Residential  Wed May 21 00:00:00 EDT 2008   59222  38.631913 -121.434879
# 1    Residential  Wed May 21 00:00:00 EDT 2008   68212  38.478902 -121.431028
# 2    Residential  Wed May 21 00:00:00 EDT 2008   68880  38.618305 -121.443839
# 3    Residential  Wed May 21 00:00:00 EDT 2008   69307  38.616835 -121.439146
# 4    Residential  Wed May 21 00:00:00 EDT 2008   81900  38.519470 -121.435768
# ..           ...                           ...     ...        ...         ...
# 980  Residential  Thu May 15 00:00:00 EDT 2008  232425  38.457679 -121.359620
# 981  Residential  Thu May 15 00:00:00 EDT 2008  234000  38.499893 -121.458890
# 982  Residential  Thu May 15 00:00:00 EDT 2008  235000  38.708824 -121.256803
# 983  Residential  Thu May 15 00:00:00 EDT 2008  235301  38.417000 -121.397424
# 984  Residential  Thu May 15 00:00:00 EDT 2008  235738  38.655245 -121.075915
#
# [985 rows x 12 columns]

# %% [markdown]
# > print(realEstTrans)
#
# > realEstTrans.head() will load the first 5 rows of the dataset
#
# > realEstTrans.head(n) will load the first n rows of the dataset
#
# > reatEstTrans.tail(n) will load the bottom n rows of the dataset
#
# Try playing around with differeng functions to get a hang on them.

# %%
#Now let's explore our dataset
#To view the headers or features we use the .columns method
realEstTrans.columns #or print(realEstTrans.columns) will work the same
# Out:
# Index(['street', 'city', 'zip', 'state', 'beds', 'baths', 'sq__ft', 'type',
#        'sale_date', 'price', 'latitude', 'longitude'],
#       dtype='object')

# %%
#To view a specific column we use the column name we want to see

#realEstTrans['street'] #This will load all the data in the 'street column'
realEstTrans['street'][0:5] #We can also give a range of rows we need from the column we need

#realEstTrans.street even this method works when the header is a single word
# Out:
# 0        3526 HIGH ST
# 1         51 OMAHA CT
# 2      2796 BRANCH ST
# 3    2805 JANETTE WAY
# 4     6001 MCMAHON DR
# Name: street, dtype: object

# %%
#We can also view multiple columns by simple specifying the names
realEstTrans[['street','type','price']].head()
# Out:
#              street         type  price
# 0      3526 HIGH ST  Residential  59222
# 1       51 OMAHA CT  Residential  68212
# 2    2796 BRANCH ST  Residential  68880
# 3  2805 JANETTE WAY  Residential  69307
# 4   6001 MCMAHON DR  Residential  81900

# %%
#To read specific row we can use the .iloc[] method
realEstTrans.iloc[2]
#realEstTrans.iloc[2:4] will give the the 3rd and 4th rows 
#Index begins from 0
# Out:
# street                     2796 BRANCH ST
# city                           SACRAMENTO
# zip                                 95815
# state                                  CA
# beds                                    2
# baths                                   1
# sq__ft                                796
# type                          Residential
# sale_date    Wed May 21 00:00:00 EDT 2008
# price                               68880
# latitude                          38.6183
# longitude                        -121.444
# Name: 2, dtype: object

# %%
#We can also use .iloc[] to read a specific data at a given location

realEstTrans.iloc[1,6] #This will give the data in the 2nd row, 7th column
# Out:
# 1167

# %% [markdown]
# > Another useful function to locate data is the .loc[] method
#
# If we want to get the rows that matches a particulat text/numeric we can use this method

# %%
realEstTrans.loc[realEstTrans['type'] == 'Condo']
#We can also use multiple conditions, try it our yourself
# Out:
#                                   street            city    zip state  beds  \
# 5                     5828 PEPPERMILL CT      SACRAMENTO  95841    CA     3
# 8        11150 TRINITY RIVER DR Unit 114  RANCHO CORDOVA  95670    CA     2
# 15                        7340 HAMDEN PL      SACRAMENTO  95842    CA     2
# 17               6236 LONGFORD DR Unit 1  CITRUS HEIGHTS  95621    CA     2
# 30          5201 LAGUNA OAKS DR Unit 140       ELK GROVE  95758    CA     2
# 34          5201 LAGUNA OAKS DR Unit 162       ELK GROVE  95758    CA     2
# 39                      2442 LARKSPUR LN      SACRAMENTO  95825    CA     1
# 40          4800 WESTLAKE PKWY Unit 2109      SACRAMENTO  95835    CA     2
# 94                          4010 ALEX LN      CARMICHAEL  95608    CA     2
# 101              4236 NATOMAS CENTRAL DR      SACRAMENTO  95834    CA     3
# 158              6272 LONGFORD DR Unit 1  CITRUS HEIGHTS  95621    CA     2
# 160          9512 EMERALD PARK DR Unit 3       ELK GROVE  95624    CA     2
# 171         5201 LAGUNA OAKS DR Unit 199       ELK GROVE  95758    CA     1
# 173         5201 LAGUNA OAKS DR Unit 172       ELK GROVE  95758    CA     1
# 190            5333 PRIMROSE DR Unit 19A       FAIR OAKS  95628    CA     2
# 192         5201 LAGUNA OAKS DR Unit 126       ELK GROVE  95758    CA     0
# 236                      2340 HURLEY WAY      SACRAMENTO  95825    CA     0
# 870      1     933  Condo  Thu May 15 00:00:00 EDT 2008   62000  38.670467
# 875      1     956  Condo  Thu May 15 00:00:00 EDT 2008   92000  38.627147
# 881      1     682  Condo  Thu May 15 00:00:00 EDT 2008  107666  38.578675
# 888      0       0  Condo  Thu May 15 00:00:00 EDT 2008  119000  38.681393
# 901      0       0  Condo  Thu May 15 00:00:00 EDT 2008  138000  38.884150
# 908      1     924  Condo  Thu May 15 00:00:00 EDT 2008  150454  38.672567
# 922      2       0  Condo  Thu May 15 00:00:00 EDT 2008  170000  38.795529
# 934      0       0  Condo  Thu May 15 00:00:00 EDT 2008  188000  38.884170
# 966      2       0  Condo  Thu May 15 00:00:00 EDT 2008  220000  38.793152
#
#       longitude
# 5   -121.327813
# 8   -121.270555
# 15  -121.351278
# 17  -121.314089
# 30  -121.444489
# 34  -121.444489
# 39  -121.403736
# 40  -121.542345
# 94  -121.312963
# 101 -121.544023
# 158 -121.313945
# 160 -121.369832
# 171 -121.444489
# 173 -121.444489
# 190 -121.276272
# 192 -121.444489
# 236 -121.408549
# 248 -121.119700
# 279 -121.260286
# 335 -121.357471
# 336 -121.401482
# 343 -121.333561
# 344 -121.359008
# 349 -121.368387
# 354 -121.357960
# 362 -121.364468
# 363 -121.288069
# 368 -121.523217
# 377 -121.371670
# 378 -121.270080
# 383 -121.328297
# 390 -121.328819
# 414 -121.300055
# 443 -121.354994
# 446 -121.549049
# 453 -121.531993
# 468 -121.097862
# 511 -121.504700
# 613 -121.428794
# 617 -121.513809
# 622 -121.542345
# 703 -121.503471
# 704 -121.289685
# 814 -121.283451
# 868 -121.359904
# 870 -121.359799
# 875 -121.500799
# 881 -121.409951
# 888 -120.996713
# 901 -121.270277
# 908 -121.356754
# 922 -121.328819
# 934 -121.270222
# 966 -121.290025

# %% [markdown]
# Let's move on to understanding our dataset

# %% [markdown]
# The most simplest way to get an overall idea of the dataset would be to use the method **.describe()**

# %%
realEstTrans.describe()
# Out:
#                 zip        beds       baths       sq__ft          price  \
# count    985.000000  985.000000  985.000000   985.000000     985.000000
# mean   95750.697462    2.911675    1.776650  1314.916751  234144.263959
# std       85.176072    1.307932    0.895371   853.048243  138365.839085
# min    95603.000000    0.000000    0.000000     0.000000    1551.000000
# 25%    95660.000000    2.000000    1.000000   952.000000  145000.000000
# 50%    95762.000000    3.000000    2.000000  1304.000000  213750.000000
# 75%    95828.000000    4.000000    2.000000  1718.000000  300000.000000
# max    95864.000000    8.000000    5.000000  5822.000000  884790.000000
#
#          latitude   longitude
# count  985.000000  985.000000
# mean    38.607732 -121.355982
# std      0.145433    0.138278
# min     38.241514 -121.551704
# 25%     38.482717 -121.446127
# 50%     38.626582 -121.376220
# 75%     38.695589 -121.295778
# max     39.020808 -120.597599

# %% [markdown]
# **The result will provide vital information such as the Standard Deviation, Mean, Mode, etc**

# %%
#Let's sort our dataset
realEstTrans.sort_values('price').head()
# Out:
#                    street         city    zip state  beds  baths  sq__ft  \
# 865  3720 VISTA DE MADERA      LINCOLN  95648    CA     3      3       0
# 866        14151 INDIO DR  SLOUGHHOUSE  95683    CA     3      4    5822
# 580               59 E ST      LINCOLN  95648    CA     3      2       0
# 584            386 1ST ST      LINCOLN  95648    CA     0      0       0
# 585            374 1ST ST      LINCOLN  95648    CA     0      0       0
#
#             type                     sale_date  price   latitude   longitude
# 865  Residential  Fri May 16 00:00:00 EDT 2008   1551  38.851645 -121.231742
# 866  Residential  Fri May 16 00:00:00 EDT 2008   2000  38.490447 -121.129337
# 580  Residential  Mon May 19 00:00:00 EDT 2008   4897  38.885794 -121.290281
# 584  Residential  Mon May 19 00:00:00 EDT 2008   4897  38.886528 -121.288869
# 585  Residential  Mon May 19 00:00:00 EDT 2008   4897  38.886525 -121.288787

# %% [markdown]
# * This will return only a copy of the sorted dataset.
#
# * It is good practice to create a variable to hold our modifications or temporary values
# > sorted_df = realEstTrans.sort_values('price')
#
# * This dataframe will hold the sorted version of the dataset
# > sorted_df

# %%
realEstTrans.sort_values('price', ascending=False).head()
#Asigning False or 0 to ascending will reverse sort the values
# Out:
#                       street             city    zip state  beds  baths  \
# 864     9401 BARREL RACER CT           WILTON  95693    CA     4      3
# 863         2982 ABERDEEN LN  EL DORADO HILLS  95762    CA     4      3
# 334         3935 EL MONTE DR           LOOMIS  95650    CA     4      4
# 157             315 JUMEL CT  EL DORADO HILLS  95762    CA     6      5
# 553  6222 CALLE MONTALVO CIR      GRANITE BAY  95746    CA     5      3
#
#      sq__ft         type                     sale_date   price   latitude  \
# 864    4400  Residential  Fri May 16 00:00:00 EDT 2008  884790  38.415298
# 863       0  Residential  Fri May 16 00:00:00 EDT 2008  879000  38.706692
# 334    1624  Residential  Tue May 20 00:00:00 EDT 2008  839000  38.813337
# 157       0  Residential  Wed May 21 00:00:00 EDT 2008  830000  38.669931
# 553    3670  Residential  Mon May 19 00:00:00 EDT 2008  760000  38.779435
#
#       longitude
# 864 -121.194858
# 863 -121.058869
# 334 -121.133348
# 157 -121.059580
# 553 -121.146676

# %%
realEstTrans.sort_values(['price','beds'], ascending=[0,1]).head()
#We can also use multiple parameters to sort our data
#ascending=[0,1] means 'price' will be in descending and beds will be in ascending orders
#Try out with different parameters to get a good understanding
# Out:
#                       street             city    zip state  beds  baths  \
# 864     9401 BARREL RACER CT           WILTON  95693    CA     4      3
# 863         2982 ABERDEEN LN  EL DORADO HILLS  95762    CA     4      3
# 334         3935 EL MONTE DR           LOOMIS  95650    CA     4      4
# 157             315 JUMEL CT  EL DORADO HILLS  95762    CA     6      5
# 553  6222 CALLE MONTALVO CIR      GRANITE BAY  95746    CA     5      3
#
#      sq__ft         type                     sale_date   price   latitude  \
# 864    4400  Residential  Fri May 16 00:00:00 EDT 2008  884790  38.415298
# 863       0  Residential  Fri May 16 00:00:00 EDT 2008  879000  38.706692
# 334    1624  Residential  Tue May 20 00:00:00 EDT 2008  839000  38.813337
# 157       0  Residential  Wed May 21 00:00:00 EDT 2008  830000  38.669931
# 553    3670  Residential  Mon May 19 00:00:00 EDT 2008  760000  38.779435
#
#       longitude
# 864 -121.194858
# 863 -121.058869
# 334 -121.133348
# 157 -121.059580
# 553 -121.146676

# %% [markdown]
# * So that's the end of part 1 of this small series
# * Try to explore all commented out codes
# * Play around to get a good knowledge on the basics
# * On the next series we will look into making changes and operations on our dataset
# * If you liked this kernal, please upvote
